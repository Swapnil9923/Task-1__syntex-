# %% [markdown]
# # Project name
# ## Overview
# **Jupyter notebooks**- are widely used for interactive computing, combining code, markdown, and outputs in a single document. Here’s a brief guide to some common Jupyter Notebook syntax and features:
# ***
# *Syntex list*
#
# 1. heading
# 2. bold
# 3. italic
# 4. print
# 5. line
#
# **Link**
# [python Documentation](https://www.python.org/doc/)
#
# **monospace font**
# `python`
#
#
# **mathematical Symbols**
#
# $ Sum $
#
# **Indeting**
# >Text that will be indented when the Markdown is rendered.
#
# **Bullet points**
# - Bullet point
# * Bullet point
#
# **coloured  boxes**
# <div class="alert alert-block alert-info">
# < jupyter notebook markdown syntex >
# </div>
#
#
#
# **Horizontal Line**
# ***
#
#
# **Image**
# ![image.png](attachment:a5d76ebc-4cbd-4bf8-838f-edd1150ade47.png)![image.png](attachment:e8b85355-fbc8-476d-8c9f-223f169c332e.png).
#
#
#
# **External link**
# --[Jupyter notebook](https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet)
#
#
# **embedded code**
#
# def f(x):
#
#       """a docstring"""
#       return X**2
#
# ```python
#
#  print "Hello Jupyter"
